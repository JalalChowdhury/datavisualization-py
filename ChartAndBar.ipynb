# %% [markdown]
# ## Line Chart

# %%
import matplotlib.pyplot as plt
 
 
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
 
# plotting the data
plt.plot(x, y)
 
# Adding title to the plot
plt.title("Line Chart")
 
# Adding label on the y-axis
plt.ylabel('Y-Axis')
 
# Adding label on the x-axis
plt.xlabel('X-Axis')
 
plt.show()

# %%
# plotting the data
plt.plot(x, y, color='green', linewidth=3, marker='o',
         markersize=15, linestyle='--')
 
# Adding title to the plot
plt.title("Line Chart")
 
# Adding label on the y-axis
plt.ylabel('Y-Axis')
 
# Adding label on the x-axis
plt.xlabel('X-Axis')
 
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
import pandas as pd
 

# plotting the data
plt.bar(x, y)
 
# Adding title to the plot
plt.title("Tips Dataset")
 
# Adding label on the y-axis
plt.ylabel('Total Bill')
 
# Adding label on the x-axis
plt.xlabel('Day')
 
plt.show()

# %% [markdown]
# ### customization

# %%
# plotting the data
plt.bar(x, y, color='green', width=5, edgecolor='blue',
        linewidth=2)
 
# Adding title to the plot
plt.title("Tips Dataset")
 
# Adding label on the y-axis
plt.ylabel('Total Bill')
 
# Adding label on the x-axis
plt.xlabel('Day')
 
plt.show()

# %% [markdown]
# ## Histogram

# %%
# Reading the tips.csv file
data = pd.read_csv('tips.csv')
 
# initializing the data
x1 = data['total_bill']
 

# plotting the data
plt.hist(x1)
 
# Adding title to the plot
plt.title("Tips Dataset")
 
# Adding label on the y-axis
plt.ylabel('Frequency')
 
# Adding label on the x-axis
plt.xlabel('Total Bill')
 
plt.show()

# %% [markdown]
# ### Customization

# %%
data = pd.read_csv('tips.csv')
 
# initializing the data
x1 = data['total_bill']
 
# plotting the data
plt.hist(x1, bins=25, color='green', edgecolor='blue',
         linestyle='--', alpha=0.5)
 
# Adding title to the plot
plt.title("Tips Dataset")
 
# Adding label on the y-axis
plt.ylabel('Frequency')
 
# Adding label on the x-axis
plt.xlabel('Total Bill')
 
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# initializing the data
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR',]
data = [23, 10, 35, 15, 12]
 
# plotting the data
plt.pie(data, labels=cars)
 
# Adding title to the plot
plt.title("Car data")
 
plt.show()

# %%
# initializing the data
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR',]
data = [23, 13, 35, 15, 12]
 
explode = [0.1, 0.5, 0, 0, 0]
 
colors = ( "orange", "cyan", "yellow",
          "grey", "green",)
 
# plotting the data
plt.pie(data, labels=cars, explode=explode, autopct='%1.2f%%',
        colors=colors, shadow=True)
 
plt.show()
