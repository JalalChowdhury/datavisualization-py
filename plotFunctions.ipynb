# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Adding Legends

# %%
import matplotlib.pyplot as plt
 
 
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
 
# plotting the data
plt.plot(x, y)
 
# Adding title to the plot
plt.title("Linear graph", fontsize=25, color="green")
 
# Adding label on the y-axis
plt.ylabel('Y-Axis')
 
# Adding label on the x-axis
plt.xlabel('X-Axis')
 
# Setting the limit of y-axis
plt.ylim(0, 80)
 
# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])
 
# Adding legends
plt.legend(["GFG"])
 
plt.show()

# %%
plt.ylabel("Y-axis ")
plt.xlabel("X-axis ")

plt.plot([9, 5], [2, 5], [4, 7, 8])

location = 0 # For the best location
legend_drawn_flag = True
plt.legend(["blue", "orange"], loc=0, frameon=legend_drawn_flag)

plt.show()

# %%
import matplotlib.pyplot as plt
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.ylabel("Y-axis ")
plt.xlabel("X-axis ")

# plt.plot([9, 5], [2, 5], [4, 7, 8])
plt.plot(x,y)
plt.plot(y,x)

location = 0 # For the best location
legend_drawn_flag = True
plt.legend(["blue", "orange"])

# plt.legend(["blue", "orange"],loc=0, frameon=legend_drawn_flag)

plt.show()

# %% [markdown]
# ## Figure class

# %%
fig = plt.figure(figsize =(7, 6), facecolor='g',
                 edgecolor='b', linewidth=7)
 
# Creating a new axes for the figure
ax = fig.add_axes([1, 1, 1, 1])
 
# Adding the data to be plotted
ax.plot(x, y)
 
# Adding title to the plot
plt.title("Linear graph", fontsize=25, color="yellow")
 
# Adding label on the y-axis
plt.ylabel('Y-Axis')
 
# Adding label on the x-axis
plt.xlabel('X-Axis')
 
# Setting the limit of y-axis
plt.ylim(0, 80)
 
# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])
 
# Adding legends
plt.legend(["GFG"])
 
plt.show()

# %% [markdown]
# # Axes Class
# ### axes class also provides methods for adding titles, legends, limits, labels, etc

# %%
fig = plt.figure(figsize = (5, 4))
 
# Adding the axes to the figure
ax = fig.add_axes([1, 1, 2, 2])
 
# plotting 1st dataset to the figure
ax1 = ax.plot(x, y)
 
# plotting 2nd dataset to the figure
ax2 = ax.plot(y, x)
 
# Setting Title
ax.set_title("Linear Graph")
 
# Setting Label
ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")
 
# Adding Legend
ax.legend(labels = ('line 1', 'line 2'))
 
plt.show()
